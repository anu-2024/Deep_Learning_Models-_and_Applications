# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjivinicarmel/AgriDataAnalysis2016/blob/main/LSTM_architecture_Demo1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.29.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.8.1)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (1.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.14.1)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (8.4.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2026.6.17)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2026.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.24.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets) (4.14.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from datasets import load_dataset

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# Loading the dataset

# %%
dataset = load_dataset("dair-ai/emotion")

train_df = pd.DataFrame(dataset["train"])
test_df = pd.DataFrame(dataset["test"])

print(train_df.head())
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md:   0%|          | 0.00/9.05k [00:00<?, ?B/s]
# split/train-00000-of-00001.parquet: reconstructing file:   0%|          |  0.00B / 1.03MB
# split/train-00000-of-00001.parquet: downloading bytes:           |  0.00B
# split/validation-00000-of-00001.parquet: reconstructing file:   0%|          |  0.00B /  127kB
# split/validation-00000-of-00001.parquet: downloading bytes:           |  0.00B
# split/test-00000-of-00001.parquet: reconstructing file:   0%|          |  0.00B /  129kB
# split/test-00000-of-00001.parquet: downloading bytes:           |  0.00B
# Generating train split:   0%|          | 0/16000 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2000 [00:00<?, ? examples/s]
#                                                 text  label
# 0                            i didnt feel humiliated      0
# 1  i can go from feeling so hopeless to so damned...      0
# 2   im grabbing a minute to post i feel greedy wrong      3
# 3  i am ever feeling nostalgic about the fireplac...      2
# 4                               i am feeling grouchy      3

# %% [markdown]
# Checking dataset

# %%
print(train_df.shape)
print(test_df.shape)

train_df['label'].value_counts()
# Out:
# (16000, 2)
# (2000, 2)
# label
# 1    5362
# 0    4666
# 3    2159
# 4    1937
# 2    1304
# 5     572
# Name: count, dtype: int64

# %% [markdown]
# Converting Labels to Emotional Name

# %%
emotion_names = {
    0:"sadness",
    1:"joy",
    2:"love",
    3:"anger",
    4:"fear",
    5:"surprise"
}

train_df["emotion"] = train_df["label"].map(emotion_names)
test_df["emotion"] = test_df["label"].map(emotion_names)

train_df.head()
# Out:
#                                                 text  label  emotion
# 0                            i didnt feel humiliated      0  sadness
# 1  i can go from feeling so hopeless to so damned...      0  sadness
# 2   im grabbing a minute to post i feel greedy wrong      3    anger
# 3  i am ever feeling nostalgic about the fireplac...      2     love
# 4                               i am feeling grouchy      3    anger

# %% [markdown]
# Label Encoding

# %%
encoder = LabelEncoder()

y_train = encoder.fit_transform(train_df["emotion"])
y_test = encoder.transform(test_df["emotion"])

# %% [markdown]
# Tokenization

# %%
vocab_size = 10000

tokenizer = Tokenizer(num_words=vocab_size,
                      oov_token="<OOV>")

tokenizer.fit_on_texts(train_df["text"])

# %% [markdown]
# Converting tokens to sequences

# %%
X_train = tokenizer.texts_to_sequences(train_df["text"])
X_test = tokenizer.texts_to_sequences(test_df["text"])

# %% [markdown]
# Padding

# %%
max_length = 40

X_train = pad_sequences(X_train,
                        maxlen=max_length,
                        padding="post")

X_test = pad_sequences(X_test,
                       maxlen=max_length,
                       padding="post")

# %% [markdown]
# Building the model

# %%
model = Sequential()

model.add(
    Embedding(input_dim=vocab_size,
              output_dim=64,
              input_length=max_length)
)

model.add(
    LSTM(64)
)

model.add(
    Dropout(0.5)
)

model.add(
    Dense(32, activation="relu")
)

model.add(
    Dense(6, activation="softmax")
)

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Compiling the model

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %% [markdown]
# Training the model

# %%
history = model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=64
)
# Out:
# Epoch 1/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9904 - loss: 0.0363 - val_accuracy: 0.8888 - val_loss: 0.5706
# Epoch 2/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9882 - loss: 0.0452 - val_accuracy: 0.8856 - val_loss: 0.5584
# Epoch 3/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9905 - loss: 0.0321 - val_accuracy: 0.8900 - val_loss: 0.5905
# Epoch 4/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9898 - loss: 0.0367 - val_accuracy: 0.8956 - val_loss: 0.5124
# Epoch 5/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9926 - loss: 0.0304 - val_accuracy: 0.8916 - val_loss: 0.5939
# Epoch 6/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9925 - loss: 0.0255 - val_accuracy: 0.8844 - val_loss: 0.6577
# Epoch 7/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9930 - loss: 0.0263 - val_accuracy: 0.8869 - val_loss: 0.7212
# Epoch 8/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9945 - loss: 0.0237 - val_accuracy: 0.8863 - val_loss: 0.7166
# Epoch 9/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9934 - loss: 0.0232 - val_accuracy: 0.8909 - val_loss: 0.6578
# Epoch 10/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9938 - loss: 0.0221 - val_accuracy: 0.8903 - val_loss: 0.6329
# Epoch 11/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9948 - loss: 0.0190 - val_accuracy: 0.8859 - val_loss: 0.7201
# Epoch 12/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9949 - loss: 0.0199 - val_accuracy: 0.8888 - val_loss: 0.7162
# Epoch 13/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9942 - loss: 0.0209 - val_accuracy: 0.8869 - val_loss: 0.7854
# Epoch 14/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9940 - loss: 0.0208 - val_accuracy: 0.8900 - val_loss: 0.6369
# Epoch 15/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9940 - loss: 0.0187 - val_accuracy: 0.8888 - val_loss: 0.6434
# Epoch 16/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9930 - loss: 0.0253 - val_accuracy: 0.8866 - val_loss: 0.6577
# Epoch 17/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9936 - loss: 0.0196 - val_accuracy: 0.8866 - val_loss: 0.7761
# Epoch 18/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9936 - loss: 0.0231 - val_accuracy: 0.8881 - val_loss: 0.6404
# Epoch 19/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9937 - loss: 0.0198 - val_accuracy: 0.8897 - val_loss: 0.6720
# Epoch 20/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9948 - loss: 0.0152 - val_accuracy: 0.8850 - val_loss: 0.7686
# Epoch 21/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9960 - loss: 0.0123 - val_accuracy: 0.8869 - val_loss: 0.7665
# Epoch 22/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9948 - loss: 0.0167 - val_accuracy: 0.8825 - val_loss: 0.8229
# Epoch 23/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9948 - loss: 0.0163 - val_accuracy: 0.8778 - val_loss: 0.7350
# Epoch 24/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9957 - loss: 0.0174 - val_accuracy: 0.8913 - val_loss: 0.6827
# Epoch 25/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9962 - loss: 0.0129 - val_accuracy: 0.8872 - val_loss: 0.7739
# Epoch 26/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9959 - loss: 0.0126 - val_accuracy: 0.8859 - val_loss: 0.7852
# Epoch 27/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9954 - loss: 0.0162 - val_accuracy: 0.8791 - val_loss: 0.7093
# Epoch 28/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9949 - loss: 0.0166 - val_accuracy: 0.8866 - val_loss: 0.7214
# Epoch 29/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9944 - loss: 0.0194 - val_accuracy: 0.8841 - val_loss: 0.6868
# Epoch 30/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9931 - loss: 0.0231 - val_accuracy: 0.8825 - val_loss: 0.7529
# Epoch 31/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9958 - loss: 0.0114 - val_accuracy: 0.8800 - val_loss: 0.7841
# Epoch 32/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9962 - loss: 0.0116 - val_accuracy: 0.8916 - val_loss: 0.7991
# Epoch 33/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9963 - loss: 0.0087 - val_accuracy: 0.8938 - val_loss: 0.7246
# Epoch 34/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9959 - loss: 0.0105 - val_accuracy: 0.8819 - val_loss: 0.8374
# Epoch 35/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9977 - loss: 0.0074 - val_accuracy: 0.8828 - val_loss: 0.8810
# Epoch 36/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9967 - loss: 0.0076 - val_accuracy: 0.8838 - val_loss: 0.8336
# Epoch 37/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9952 - loss: 0.0126 - val_accuracy: 0.8850 - val_loss: 0.8578
# Epoch 38/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9967 - loss: 0.0070 - val_accuracy: 0.8859 - val_loss: 0.9907
# Epoch 39/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9955 - loss: 0.0152 - val_accuracy: 0.8797 - val_loss: 0.8188
# Epoch 40/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9961 - loss: 0.0131 - val_accuracy: 0.8831 - val_loss: 0.7932
# Epoch 41/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9945 - loss: 0.0187 - val_accuracy: 0.8841 - val_loss: 0.7347
# Epoch 42/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9958 - loss: 0.0135 - val_accuracy: 0.8841 - val_loss: 0.7651
# Epoch 43/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9954 - loss: 0.0128 - val_accuracy: 0.8834 - val_loss: 0.7658
# Epoch 44/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9966 - loss: 0.0095 - val_accuracy: 0.8844 - val_loss: 0.8462
# Epoch 45/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9971 - loss: 0.0078 - val_accuracy: 0.8831 - val_loss: 0.9381
# Epoch 46/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9967 - loss: 0.0077 - val_accuracy: 0.8866 - val_loss: 0.8350
# Epoch 47/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9975 - loss: 0.0069 - val_accuracy: 0.8822 - val_loss: 0.9449
# Epoch 48/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9975 - loss: 0.0048 - val_accuracy: 0.8863 - val_loss: 1.0024
# Epoch 49/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9965 - loss: 0.0105 - val_accuracy: 0.8875 - val_loss: 0.8504
# Epoch 50/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9962 - loss: 0.0088 - val_accuracy: 0.8800 - val_loss: 0.9499

# %% [markdown]
# Accuracy Plot

# %%
plt.figure(figsize=(8,5))

plt.plot(history.history["accuracy"], label="Train")
plt.plot(history.history["val_accuracy"], label="Validation")

plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training Accuracy")

plt.legend()
plt.show()

# %% [markdown]
# Loss Plot

# %%
plt.figure(figsize=(8,5))

plt.plot(history.history["loss"], label="Train")
plt.plot(history.history["val_loss"], label="Validation")

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss")

plt.legend()
plt.show()

# %% [markdown]
# Evaluation Of Model

# %%
loss, accuracy = model.evaluate(X_test, y_test)

print("Test Accuracy :", accuracy)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8915 - loss: 0.9074
# Test Accuracy : 0.8914999961853027

# %% [markdown]
# Classification Model

# %%
pred = model.predict(X_test)

pred_classes = np.argmax(pred, axis=1)

print(classification_report(y_test, pred_classes))
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88       275
#            1       0.88      0.79      0.84       224
#            2       0.92      0.91      0.92       695
#            3       0.79      0.81      0.80       159
#            4       0.92      0.96      0.94       581
#            5       0.65      0.76      0.70        66
#
#     accuracy                           0.89      2000
#    macro avg       0.84      0.85      0.84      2000
# weighted avg       0.89      0.89      0.89      2000

# %% [markdown]
# Predicting your own sentence

# %%
sentence = [" prepared  for exam"]

seq = tokenizer.texts_to_sequences(sentence)
seq = pad_sequences(seq, maxlen=max_length, padding="post")

prediction = model.predict(seq)

emotion = encoder.inverse_transform([np.argmax(prediction)])

print("Predicted Emotion:", emotion[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Predicted Emotion: fear
